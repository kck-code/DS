# %%
# !pip install openpyxl

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# !wget https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Out:
# --2025-08-19 13:02:23--  https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘online+retail.zip’
#
# online+retail.zip       [        <=>         ]  22.62M  12.3MB/s    in 1.8s
#
# 2025-08-19 13:02:26 (12.3 MB/s) - ‘online+retail.zip’ saved [23715478]

# %%
# !unzip /content/online+retail.zip
# Out:
# Archive:  /content/online+retail.zip
#  extracting: Online Retail.xlsx

# %%
df1 = pd.read_excel('/content/Online Retail.xlsx', dtype={'InvoiceNo':'string', 'StockCode':'string', 'Description':'string', 'Country':'string'})
df1.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
df1.shape
# Out:
# (541909, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  string
#  1   StockCode    541909 non-null  string
#  2   Description  540455 non-null  string
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  string
# dtypes: datetime64[ns](1), float64(2), int64(1), string(4)
# memory usage: 33.1 MB

# %% [markdown]
# #### Data Cleaning: Handle Missing Values

# %%
df1.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df1[df1.Description.isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139        <NA>        56 2010-12-01 11:52:00
# 1970      536545     21134        <NA>         1 2010-12-01 14:32:00
# 1971      536546     22145        <NA>         1 2010-12-01 14:33:00
# 1972      536547     37509        <NA>         1 2010-12-01 14:33:00
# 1987      536549    85226A        <NA>         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581        <NA>        -2 2011-12-07 18:26:00
# 535326    581203     23406        <NA>        15 2011-12-07 18:31:00
# 535332    581209     21620        <NA>         6 2011-12-07 18:35:00
# 536981    581234     72817        <NA>        27 2011-12-08 10:33:00
# 538554    581408     85175        <NA>        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# ...

# %%
df1[df1.StockCode=='22139'].Description.mode()
# Out:
# 0    RETROSPOT TEA SET CERAMIC 11 PC
# Name: Description, dtype: string

# %%
most_freq = df1[['StockCode', 'Description']].value_counts().reset_index()
most_freq
# Out:
#      StockCode                         Description  count
# 0       85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1        22423            REGENCY CAKESTAND 3 TIER   2200
# 2       85099B             JUMBO BAG RED RETROSPOT   2159
# 3        47566                       PARTY BUNTING   1727
# 4        20725             LUNCH BAG RED RETROSPOT   1638
# ...        ...                                 ...    ...
# 4787     21491     SET OF THREE VINTAGE GIFT WRAPS      1
# 4788    84876D                             damaged      1
# 4789     20827                             damages      1
# 4790     20832                               check      1
# 4791     21578                                   ?      1
#
# [4792 rows x 3 columns]

# %%
# @title count

from matplotlib import pyplot as plt
most_freq['count'].plot(kind='line', figsize=(8, 4), title='count')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
most_freq[most_freq.StockCode=='85123A'].head(1)
# Out:
#   StockCode                         Description  count
# 0    85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302

# %%
most_freq = most_freq.groupby('StockCode').head(1)
most_freq
# Out:
#      StockCode                          Description  count
# 0       85123A   WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1        22423             REGENCY CAKESTAND 3 TIER   2200
# 2       85099B              JUMBO BAG RED RETROSPOT   2159
# 3        47566                        PARTY BUNTING   1727
# 4        20725              LUNCH BAG RED RETROSPOT   1638
# ...        ...                                  ...    ...
# 4755     37503      TEA TIME CAKE STAND IN GIFT BOX      1
# 4773     37461                     FUNKY MONKEY MUG      1
# 4775     37474  SET/4 2 TONE EGG SHAPE MIXING BOWLS      1
# 4782     22145      CHRISTMAS CRAFT HEART STOCKING       1
# 4787     21491      SET OF THREE VINTAGE GIFT WRAPS      1
#
# [3958 rows x 3 columns]

# %%
most_freq.columns = ['StockCode', 'freq_Description', 'count']
df2 = df1.merge(most_freq, on='StockCode', how='left')
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
#                       freq_Description   count
# 0   WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1                  WHITE METAL LANTERN   328.0
# ...

# %%
df2['Description'] = df2['freq_Description']
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
#                       freq_Description   count
# 0   WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1                  WHITE METAL LANTERN   328.0
# ...

# %%
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description            112
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          135080
# Country                  0
# freq_Description       112
# count                  112
# dtype: int64

# %%
df2.dropna(subset=['Description'], inplace=True)
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description              0
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          134968
# Country                  0
# freq_Description         0
# count                    0
# dtype: int64

# %%
df2.drop(columns=['freq_Description'], inplace=True)
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country   count
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2302.0
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   328.0
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   293.0
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   473.0
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   449.0

# %%
df2.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541797.000000                         541797  541797.000000
# mean        9.555919  2011-07-04 14:06:48.671255296       4.612067
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:36:00       1.250000
# 50%         3.000000            2011-07-20 08:59:00       2.080000
# 75%        10.000000            2011-10-19 11:41:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.103428                            NaN      96.769831
#
#           CustomerID          count
# count  406829.000000  541797.000000
# mean    15287.690570     424.567967
# min     12346.000000       1.000000
# 25%     13953.000000     151.000000
# 50%     15152.000000     303.000000
# 75%     16791.000000     573.000000
# max     18287.000000    2302.000000
# std      1713.600303     391.068884

# %%
df2[df2.UnitPrice<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country  count
# 299983  -11062.06         NaN  United Kingdom    3.0
# 299984  -11062.06         NaN  United Kingdom    3.0

# %%
df3 = df2[(df2.UnitPrice>0) & (df2.Quantity>0)]
df3.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  530104.000000                         530104  530104.000000
# mean       10.542037  2011-07-04 20:16:05.225087744       3.907625
# min         1.000000            2010-12-01 08:26:00       0.001000
# 25%         1.000000            2011-03-28 12:22:00       1.250000
# 50%         3.000000            2011-07-20 12:58:00       2.080000
# 75%        10.000000            2011-10-19 12:39:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   13541.330000
# std       155.524124                            NaN      35.915681
#
#           CustomerID          count
# count  397884.000000  530104.000000
# mean    15294.423453     424.852891
# min     12346.000000       1.000000
# 25%     13969.000000     152.000000
# 50%     15159.000000     303.000000
# 75%     16795.000000     573.000000
# max     18287.000000    2302.000000
# std      1713.141560     389.658735

# %%
df3.Quantity.quantile(0.9999)
# Out:
# np.float64(1439.8763999990188)

# %%
df3[df3.Quantity>1500]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 4850      536809     84950       ASSORTED COLOUR T-LIGHT HOLDER      1824
# 4945      536830     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 25920     538420     17096    ASSORTED LAQUERED INCENSE HOLDERS      1728
# 32671     539101     22693   GROW A FLYTRAP OR SUNFLOWER IN TIN      2400
# 52709     540815    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1930
# 52710     540815     21175          GIN + TONIC DIET METAL SIGN      2000
# 52711     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 80742     543057     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      2592
# 87631     543669     22693   GROW A FLYTRAP OR SUNFLOWER IN TIN      2400
# 91772     544152     18007  ESSENTIAL BALM 3.5g TIN IN ENVELOPE      2400
# 97432     544612     22053                EMPIRE DESIGN ROSETTE      3906
# ...

# %% [markdown]
# #### Feature Engineering: Create New Columns

# %%
df4 = df3.copy()
df4['TotalSales'] = df4['Quantity'] * df4['UnitPrice']
df4.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country   count  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2302.0
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   328.0
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   293.0
#
#    TotalSales
# 0       15.30
# 1       20.34
# 2       22.00

# %%
df4['Month'] = df4['InvoiceDate'].dt.month
df4.sample(5)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 137244    548150    35809A           ENAMEL PINK TEA CONTAINER         6
# 342033    566789     23153    ZINC SWEETHEART WIRE LETTER RACK         4
# 135769    547910    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 359175    568179     22223            CAKE PLATE LOVEBIRD PINK         3
# 256669    559505    16156S              WRAP PINK FAIRY CAKES         25
#
#                InvoiceDate  UnitPrice  CustomerID         Country   count  \
# 137244 2011-03-29 12:55:00       0.83     17315.0  United Kingdom    64.0
# 342033 2011-09-15 10:35:00       3.75     13134.0  United Kingdom    91.0
# 135769 2011-03-28 12:23:00       2.95     14159.0  United Kingdom  2302.0
# 359175 2011-09-25 13:39:00       4.95     12545.0           Spain    79.0
# 256669 2011-07-08 15:16:00       0.42     16398.0  United Kingdom   167.0
#
#         TotalSales  Month
# 137244        4.98      3
# 342033       15.00      9
# ...

# %% [markdown]
# #### Visualization & EDA

# %% [markdown]
# #####1. Plot Monthly Sales

# %%
monthly_sales = df4.groupby("Month").TotalSales.sum()
monthly_sales.plot(kind='line', figsize=(8, 4), title='Monthly Sales', marker='o')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid()
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# **Insights**
#
# Total sales started rising up in August having a peek in November. This is likely due to the holiday season at the end of the year.

# %% [markdown]
# ##### 2. Top 5 Countries

# %%
country_sales = df4.groupby('Country')['TotalSales'].sum().sort_values(ascending=False)
top_5_countries = country_sales.head(5)
top_5_countries
# Out:
# Country
# United Kingdom    9025222.084
# Netherlands        285446.340
# EIRE               283453.960
# Germany            228867.140
# France             209715.110
# Name: TotalSales, dtype: float64

# %%
top_5_countries.plot(kind='barh', figsize=(8, 4), title='Top 5 Countries by Total Sales')
plt.xlabel('Total Sales')
plt.ylabel('Country')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()

# %%
country_wise_sales = df4.groupby('Country')['TotalSales'].sum()
total_sales = country_wise_sales.sum()

top_5_countries_percentage = country_wise_sales.sort_values(ascending=False).head(5)
percentages = (top_5_countries_percentage / total_sales) * 100

plt.figure(figsize=(8, 4))
bars = plt.barh(top_5_countries.index, percentages)
plt.xlabel('Percentage (%)')
plt.ylabel('Country')
plt.grid(axis='x')
plt.title('Top 5 Countries by Percentage of Total Sales')

# Add percentage labels to the bars
for bar, percentage in zip(bars, percentages):
    plt.text(bar.get_width() + 1, bar.get_y() + bar.get_height() / 2, f'{percentage:.1f}%', ha='left', va='center')

plt.show()

# %% [markdown]
# ##### 3. Top 5 products

# %%
product_wise_sales = df4.groupby('StockCode')['TotalSales'].sum()

top_5_products = product_wise_sales.sort_values(ascending=False).head(5)
top_5_products.plot(kind='barh', figsize=(8, 4), title='Top 5 Products by Total Sales')
plt.xlabel('Total Sales')
plt.ylabel('Product')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
product_wise_sales.sort_values(ascending=False)
# Out:
# StockCode
# DOT       206248.770
# 22423     174484.740
# 23843     168469.600
# 85123A    104518.800
# 47566      99504.330
#              ...
# 90084          0.850
# 21268          0.840
# 51014c         0.830
# 84227          0.420
# PADS           0.003
# Name: TotalSales, Length: 3922, dtype: float64

# %%
df4[df4.StockCode=='DOT']
# Out:
#        InvoiceNo StockCode     Description  Quantity         InvoiceDate  \
# 1814      536544       DOT  DOTCOM POSTAGE         1 2010-12-01 14:32:00
# 3041      536592       DOT  DOTCOM POSTAGE         1 2010-12-01 17:06:00
# 5450      536862       DOT  DOTCOM POSTAGE         1 2010-12-03 11:13:00
# 5545      536864       DOT  DOTCOM POSTAGE         1 2010-12-03 11:27:00
# 5685      536865       DOT  DOTCOM POSTAGE         1 2010-12-03 11:28:00
# ...          ...       ...             ...       ...                 ...
# 536834    581219       DOT  DOTCOM POSTAGE         1 2011-12-08 09:28:00
# 537254    581238       DOT  DOTCOM POSTAGE         1 2011-12-08 10:53:00
# 539368    581439       DOT  DOTCOM POSTAGE         1 2011-12-08 16:30:00
# 540908    581492       DOT  DOTCOM POSTAGE         1 2011-12-09 10:03:00
# 541540    581498       DOT  DOTCOM POSTAGE         1 2011-12-09 10:26:00
#
#         UnitPrice  CustomerID         Country  count  TotalSales  Month
# ...

# %%
for stock_code in top_5_products.index:
  description = df4[df4.StockCode==stock_code].Description.iloc[0]
  print(f'{stock_code}: {description}')
# Out:
# DOT: DOTCOM POSTAGE
# 22423: REGENCY CAKESTAND 3 TIER
# 23843: PAPER CRAFT , LITTLE BIRDIE
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# 47566: PARTY BUNTING

# %%
product_wise_sales = df4.groupby('StockCode')['TotalSales'].sum()
total_sales = product_wise_sales.sum()

top_5_products_percentage = (product_wise_sales / total_sales * 100).sort_values(ascending=False).head(5)

plt.figure(figsize=(8, 4))
ax = top_5_products_percentage.plot(kind='barh', title='Top 5 Products by Total Sales Percentage')
plt.xlabel('Percentage (%)')
plt.ylabel('Product')
plt.gca().spines[['top', 'right']].set_visible(False)

# Add percentage labels to the bars
for i, v in enumerate(top_5_products_percentage):
    ax.text(v + 0.5, i, f'{v:.2f}%', va='center')

plt.show()

# %% [markdown]
# ##### 4. RFM Analysis

# %%
current_dt = df4['InvoiceDate'].max() + pd.Timedelta(days=1)
current_dt
# Out:
# Timestamp('2011-12-10 12:50:00')

# %%
rfm = df4.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (current_dt - x.max()).days,
    'InvoiceNo': 'count',
    'TotalSales': 'sum'
})
rfm.columns = ['Recency', 'Frequency', 'Monetary']
rfm.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          1  77183.60
# 12347.0           2        182   4310.00
# 12348.0          75         31   1797.24
# 12349.0          19         73   1757.55
# 12350.0         310         17    334.40

# %%
rfm['R_Segment'] = pd.qcut(rfm['Recency'], 4, labels=[4, 3, 2, 1])
rfm['F_Segment'] = pd.qcut(rfm['Frequency'], 4, labels=[1, 2, 3, 4])
rfm['M_Segment'] = pd.qcut(rfm['Monetary'], 4, labels=[1, 2, 3, 4])
rfm['RFM_Score'] = rfm[['R_Segment', 'F_Segment', 'M_Segment']].sum(axis=1)
rfm
# Out:
#             Recency  Frequency  Monetary R_Segment F_Segment M_Segment  \
# CustomerID
# 12346.0         326          1  77183.60         1         1         4
# 12347.0           2        182   4310.00         4         4         4
# 12348.0          75         31   1797.24         2         2         4
# 12349.0          19         73   1757.55         3         3         4
# 12350.0         310         17    334.40         1         1         2
# ...             ...        ...       ...       ...       ...       ...
# 18280.0         278         10    180.60         1         1         1
# 18281.0         181          7     80.82         1         1         1
# 18282.0           8         12    178.05         4         1         1
# 18283.0           4        756   2094.88         4         4         4
# 18287.0          43         70   1837.28         3         3         4
#
#             RFM_Score
# CustomerID
# 12346.0             6
# 12347.0            12
# ...

# %%
rfm.sort_values('RFM_Score', ascending=False)
# Out:
#             Recency  Frequency  Monetary R_Segment F_Segment M_Segment  \
# CustomerID
# 18283.0           4        756   2094.88         4         4         4
# 18245.0           7        175   2567.06         4         4         4
# 18241.0          10        104   2073.09         4         4         4
# 18229.0          12        164   7276.90         4         4         4
# 18225.0           3        271   5509.12         4         4         4
# ...             ...        ...       ...       ...       ...       ...
# 16471.0         275         13    223.95         1         1         1
# 18224.0         264         10    158.95         1         1         1
# 18220.0         227          2    305.28         1         1         1
# 13011.0         372          3     50.55         1         1         1
# 13008.0         323         14    229.47         1         1         1
#
#             RFM_Score
# CustomerID
# 18283.0            12
# 18245.0            12
# ...

# %% [markdown]
# ##### 5. Customer Churn Analysis

# %%
customer_last_purchase = df4.groupby('CustomerID')['InvoiceDate'].max()
customer_last_purchase.head(5)
# Out:
# CustomerID
# 12346.0   2011-01-18 10:01:00
# 12347.0   2011-12-07 15:52:00
# 12348.0   2011-09-25 13:13:00
# 12349.0   2011-11-21 09:51:00
# 12350.0   2011-02-02 16:01:00
# Name: InvoiceDate, dtype: datetime64[ns]

# %%
type(customer_last_purchase)
# Out:
# pandas.core.series.Series

# %%
current_dt
# Out:
# Timestamp('2011-12-10 12:50:00')

# %%
customer_last_purchase = (current_dt - customer_last_purchase).dt.days
customer_last_purchase.head(5)
# Out:
# CustomerID
# 12346.0    326
# 12347.0      2
# 12348.0     75
# 12349.0     19
# 12350.0    310
# Name: InvoiceDate, dtype: int64

# %%
churn_threshold = 90
churned_customers = customer_last_purchase[customer_last_purchase > churn_threshold]
churned_customers.head(5)
# Out:
# CustomerID
# 12346.0    326
# 12350.0    310
# 12353.0    204
# 12354.0    232
# 12355.0    214
# Name: InvoiceDate, dtype: int64

# %%
print('Number of Churned Customers:', len(churned_customers))
plt.figure(figsize=(8, 4))
plt.hist(customer_last_purchase, bins=50, edgecolor='k')
plt.axvline(churn_threshold, color='r', linestyle='--', label=f'Churn Threshold ({churn_threshold} days)')
plt.xlabel('Days Since Last Purchase')
plt.ylabel('Number of Customers')
# Out:
# Number of Churned Customers: 1449
# Text(0, 0.5, 'Number of Customers')
